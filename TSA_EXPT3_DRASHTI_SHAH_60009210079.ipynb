# %% [markdown]
# <a href="https://colab.research.google.com/github/drashtikshah/TSA-experiments-/blob/main/TSA_EXPT3_DRASHTI_SHAH_60009210079.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Smart_City_index_headers.csv")
df
# Out:
#       Id           City      Country  Smart_Mobility   Smart_Environment  \
# 0      1           Oslo       Norway             6480               6512
# 1      2         Bergen       Norway             7097               6876
# 2      3      Amsterdam  Netherlands             7540               5558
# 3      4     Copenhagen      Denmark             7490               7920
# 4      5      Stockholm       Sweden             6122               7692
# ..   ...            ...          ...              ...                ...
# 97    98           Riga       Latvia             4152               4584
# 98    99        Beijing        China             7610               2998
# 99   100  St Petersburg       Russia             4588               2908
# 100  101        Calgary       Canada             6675               4052
# 101  102       Edmonton       Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# ...

# %%
df.isnull().sum()
# Out:
# Id                                   0
# City                                 0
# Country                              0
# Smart_Mobility                       0
# Smart_Environment                    0
# Smart_Government                     0
# Smart_Economy                        0
# Smart_People                         0
# Smart_Living                         0
# SmartCity_Index                      0
# SmartCity_Index_relative_Edmonton    0
# dtype: int64

# %%
df.describe()
# Out:
#                Id  Smart_Mobility   Smart_Environment  Smart_Government   \
# count  102.000000       102.000000         102.000000         102.000000
# mean    51.500000      5759.401961        5943.500000        5893.803922
# std     29.588849      1214.030137        1724.032171        1153.375297
# min      1.000000      3175.000000        1850.000000        2806.000000
# 25%     26.250000      4809.750000        4530.500000        5143.000000
# 50%     51.500000      5651.500000        6495.000000        5911.000000
# 75%     76.750000      6763.750000        7310.000000        6581.500000
# max    102.000000      8110.000000        8844.000000        8726.000000
#
#        Smart_Economy   Smart_People  Smart_Living  SmartCity_Index  \
# count      102.000000    102.000000    102.000000       102.000000
# mean      6131.803922   5874.049020   6377.039216      5991.911765
# std       1801.555148   1449.096341   2286.397477       852.775180
# ...

# %%
df['SmartCity_Index_relative_Edmonton'].unique()
# Out:
# array([  666,   823,   839,   698,   340,   880,   298,   414,   341,
#          380,   512,   567,   299,   247,   379,   190,   346,   -35,
#          448,   679,    57,   409,  -136,    79,  -718,   -17,  -348,
#          602,   -79,  -194,   -83,   -63,   -41,  -217,  -145,   204,
#          332,   177,   -81,    90,   230,   -30,  -288,  -153,   344,
#          -76,  -430,  -304,    31,  -485,   263,  -581,  -412,  -558,
#          -24,  -587,    70,  -468,  -678,  -176,  -969,  -998, -1158,
#         -204, -1093,  -393,  -560,  -182,  -750, -1923,  -665, -1505,
#         -231,  -792, -2175, -1110, -1133, -1258, -1088,  -783, -2019,
#        -1180, -1792, -1384, -1029, -1933, -2160, -1759, -1232, -1432,
#        -1910, -1453, -2244, -1820, -1638, -1906, -2108, -1760, -2023,
#        -2281,   206,     0])

# %%
df.agg({'Smart_People': ['count','min', 'max', 'mean']})
# Out:
#        Smart_People
# count     102.00000
# min      2825.00000
# max      9695.00000
# mean     5874.04902

# %%
df.groupby('Country')['Smart_People'].sum()
# Out:
# Country
# Australia               21981
# Austria                  8580
# Belgium                  6680
# Canada                  42675
# China                   13991
# Czech Republic           5315
# Denmark                 25508
# Estonia                  4955
# Finland                 59800
# France                  37806
# Germany                 53086
# Hungary                  7260
# Iceland                  7285
# Ireland                  5425
# Israel                   4113
# Italy                   51262
# Japan                    7561
# Latvia                   3745
# Luxembourg               4723
# Malaysia                 3313
# Netherlands              7098
# New Zealand              7855
# Norway                  31821
# Portugal                 3560
# Russia                   9533
# Singapore                9695
# Slovakia                 5485
# Slovenia                 5503
# South Korea             16495
# Spain                   11450
# ...

# %%
df.groupby('Country').agg({'Smart_People':['mean','min','max']})
# Out:
#                      Smart_People
#                              mean   min   max
# Country
# Australia             5495.250000  4678  7305
# Austria               8580.000000  8580  8580
# Belgium               6680.000000  6680  6680
# Canada                7112.500000  6200  8465
# China                 4663.666667  4385  5183
# Czech Republic        5315.000000  5315  5315
# Denmark               6377.000000  5780  6955
# Estonia               4955.000000  4955  4955
# Finland               5980.000000  4385  7523
# France                5400.857143  3425  7075
# Germany               5308.600000  3108  6853
# Hungary               7260.000000  7260  7260
# Iceland               7285.000000  7285  7285
# Ireland               5425.000000  5425  5425
# Israel                4113.000000  4113  4113
# Italy                 4660.181818  2825  6185
# Japan                 3780.500000  3403  4158
# Latvia                3745.000000  3745  3745
# ...
